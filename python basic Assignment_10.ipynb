# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?

# %% [markdown]
# The shutil.copy() function will copy a single file, while shutil.copytree() will copy an entire folder, along with all its contents.

# %% [markdown]
# 2. What function is used to rename files??

# %% [markdown]
# The shutil.move() function is used for renaming files, as well as moving them.

# %% [markdown]
# 3. What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# The send2trash functions will move a file or folder to the recycle bin, while shutil functions will permanently delete files and folders.

# %% [markdown]
# 4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

# %% [markdown]
# The zipfile.ZipFile() function is equivalent to the open() function; the first argument is the filename, and the second argument is the mode to open the ZIP file in (read, write, or append).

# %% [markdown]
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
# Write a program that walks through a folder tree 
# and searches for files with a certain file extension (such as .pdf or .jpg).
# Copy these files from whatever location they are in to a new folder.

import os, shutil

def selectiveCopy(source, extensions, destFolder):
    folder = os.path.abspath(source)
    destFolder = os.path.abspath(destFolder)
    print('Looking in', source, 'for files with extensions of', ', '.join(extensions))
    for foldername, subfolders, filenames in os.walk(source):
        for filename in filenames:
            name, extension = os.path.splitext(filename)
            if extension in extensions:
                fileAbsPath = foldername + os.path.sep + filename
                print('Coping', fileAbsPath, 'to', destFolder)
                shutil.copy(fileAbsPath, destFolder)

extensions = ['.mp4', '.pdf','.jpg']
source = "/home/prince/Desktop/onedrive/Books"
destFolder = "/home/prince/Desktop/book/"
selectiveCopy(source, extensions, destFolder)
# Out:
# Looking in /home/prince/Desktop/onedrive/Books for files with extensions of .mp4, .pdf, .jpg
# Coping /home/prince/Desktop/onedrive/Books/Algorithms to Live By_ The Computer Science of Human Decisions - PDF Room (1).pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Automate the Boring Stuff with Python - Practical Programming for Total Beginners by Al Sweigart.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Basic graph theory ppt.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Eulerian and hemilton graph pdf.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Graph theory basics.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Hands On Machine Learning (Early Release).pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Hands on machine learning latest edition.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/ISLRv2_website.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Intro to data science.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Learn Python The Hard Way 3rd Edition V413HAV.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Learning Algorithms Through Programming and Puzzle Solving ( PDFDrive.com ).pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Math for Programmers 3D Graphics, Machine Learning and Simulations with Python by Paul Orland.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Mathematics for machine learning.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Naked Statistics_ Stripping the Dread from the Data - PDF Room.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Planer graphs ppt.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Practical Statistics for Data Scientists 50 Essential Concepts Using R and Python (2020)-39937.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Pro Python.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Python crash course.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Python-for-Data-Analysis-2nd-Edition.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/Think stats.pdf to /home/prince/Desktop/book
# Coping /home/prince/Desktop/onedrive/Books/beyond-the-basic-stuff-with-python-by-al-sweigart.pdf to /home/prince/Desktop/book
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_34911/4263665479.py in <module>
#      20 source = "/home/prince/Desktop/onedrive/Books"
#      21 destFolder = "/home/prince/Desktop/book/"
# ---> 22 selectiveCopy(source, extensions, destFolder)
#
# /tmp/ipykernel_34911/4263665479.py in selectiveCopy(source, extensions, destFolder)
#      15                 fileAbsPath = foldername + os.path.sep + filename
#      16                 print('Coping', fileAbsPath, 'to', destFolder)
# ---> 17                 shutil.copy(fileAbsPath, destFolder)
#      18
#      19 extensions = ['.mp4', '.pdf','.jpg']
#
# ~/anaconda3/lib/python3.9/shutil.py in copy(src, dst, follow_symlinks)
#     424     if os.path.isdir(dst):
#     425         dst = os.path.join(dst, os.path.basename(src))
# --> 426     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     427     copymode(src, dst, follow_symlinks=follow_symlinks)
#     428     return dst
#
# ~/anaconda3/lib/python3.9/shutil.py in copyfile(src, dst, follow_symlinks)
#     274                 elif _USE_CP_SENDFILE:
#     275                     try:
# --> 276                         _fastcopy_sendfile(fsrc, fdst)
#     277                         return dst
#     278                     except _GiveupOnFastCopy:
#
# ~/anaconda3/lib/python3.9/shutil.py in _fastcopy_sendfile(fsrc, fdst)
#     150     while True:
#     151         try:
# --> 152             sent = os.sendfile(outfd, infd, offset, blocksize)
#     153         except OSError as err:
#     154             # ...in oder to have a more informative exception.
#
# KeyboardInterrupt:
